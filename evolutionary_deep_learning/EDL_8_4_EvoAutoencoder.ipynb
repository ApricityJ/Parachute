# %%
import numpy as np
import tensorflow as tf
import numpy as np
import random

from tensorflow.keras.datasets import mnist
from tensorflow.keras import layers, models, Input, Model
from tensorflow.keras.callbacks import EarlyStopping

from IPython import display
from IPython.display import clear_output
import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model
from livelossplot import PlotLosses
plt.gray()

#DEAP
from deap import algorithms
from deap import base
from deap import benchmarks
from deap import creator
from deap import tools

# %% [markdown]
# Load Fashion Data

# %%
# load dataset
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.fashion_mnist.load_data()

# split dataset
train_images = train_images.reshape(train_images.shape[0], 28, 28, 1).astype("float32") / 255.0
test_images = test_images.reshape(test_images.shape[0], 28, 28, 1).astype("float32") / 255.0

# reduce dataset for demonstration
#train_images = train_images[1000:]
#test_images = test_images[100:]

# %% [markdown]
# Setup class names and labels for visualization, not training

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# Plot some images.

# %%
import math

def plot_data(num_images, images, labels):
  grid = math.ceil(math.sqrt(num_images))
  plt.figure(figsize=(grid*2,grid*2))
  for i in range(num_images):
      plt.subplot(grid,grid,i+1)
      plt.xticks([])
      plt.yticks([])
      plt.grid(False)     
      plt.imshow(images[i].reshape(28,28))
      plt.xlabel(class_names[labels[i]])      
  plt.show()

plot_data(25, train_images, train_labels)

# %% [markdown]
# STAGE 1: Auto-encoders

# %% [markdown]
# Build the Encoder

# %%
# input layer
input_layer = Input(shape=(28, 28, 1))

# encoding architecture
encoded_layer1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(input_layer)
encoded_layer1 = layers.MaxPool2D( (2, 2), padding='same')(encoded_layer1)
encoded_layer2 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(encoded_layer1)
encoded_layer2 = layers.MaxPool2D( (2, 2), padding='same')(encoded_layer2)
encoded_layer3 = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(encoded_layer2)
latent_view    = layers.MaxPool2D( (2, 2), padding='same')(encoded_layer3)

# %% [markdown]
# Build the Decoder

# %%
#decoding architecture
decoded_layer1 = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(latent_view)
decoded_layer1 = layers.UpSampling2D((2, 2))(decoded_layer1)
decoded_layer2 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(decoded_layer1)
decoded_layer2 = layers.UpSampling2D((2, 2))(decoded_layer2)
decoded_layer3 = layers.Conv2D(64, (3, 3), activation='relu')(decoded_layer2)
decoded_layer3 = layers.UpSampling2D((2, 2))(decoded_layer3)
#output layer
output_layer   = layers.Conv2D(1, (3, 3), padding='same')(decoded_layer3)

# %% [markdown]
# Build the Model

# %%
# compile the model
model = Model(input_layer, output_layer)
model.compile(optimizer='adam', loss='mse')
model.summary()
plot_model(model)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 64)        640
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 64)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 32)        18464
#
#  max_pooling2d_1 (MaxPoolin  (None, 7, 7, 32)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 16)          4624
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 16)          0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 16)          2320
#
#  up_sampling2d (UpSampling2  (None, 8, 8, 16)          0
#  D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 32)          4640
#
#  up_sampling2d_1 (UpSamplin  (None, 16, 16, 32)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 14, 14, 64)        18496
#
#  up_sampling2d_2 (UpSamplin  (None, 28, 28, 64)        0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 28, 28, 1)         577
#
# =================================================================
# Total params: 49761 (194.38 KB)
# Trainable params: 49761 (194.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
history_loss = []
history_val_loss = []

def add_history(history):
  history_loss.append(history.history["loss"])
  history_val_loss.append(history.history["val_loss"])

def reset_history():
  global history_loss
  global history_val_loss
  history_loss = []
  history_val_loss = []
  return []

def plot_results(num_images, images, labels, history):
  add_history(history)
  grid = math.ceil(math.sqrt(num_images))
  plt.figure(figsize=(grid*2,grid*2))
  for i in range(num_images):
      plt.subplot(grid,grid,i+1)
      plt.xticks([])
      plt.yticks([])
      plt.grid(False)     
      plt.imshow(images[i].reshape(28,28))
      plt.xlabel(class_names[labels[i]])      
  plt.show()
  plt.plot(history_loss, label='loss')
  plt.plot(history_val_loss, label='val_loss')
  plt.legend()
  plt.show()

# %%
EPOCHS = 3
history = reset_history()

for i in range(EPOCHS):
  history = model.fit(train_images, train_images, epochs=1, batch_size=2048, validation_data=(test_images, test_images))
  pred_images = model.predict(test_images[:25])
  clear_output()
  plot_results(25, pred_images[:25], test_labels[:25], history)

# %%
#@title Constants
max_layers = 10
max_neurons = 128
min_neurons = 16
max_kernel = 3
min_kernel = 3
max_pool = 2
min_pool = 2

CONV_LAYER = -1
CONV_LAYER_LEN = 4
BN_LAYER = -3
BN_LAYER_LEN = 1
DROPOUT_LAYER = -4
DROPOUT_LAYER_LEN = 2
UPCONV_LAYER = -2
UPCONV_LAYER_LEN = 4

# %%
#@title Encoding scheme
def generate_neurons():
  return random.randint(min_neurons, max_neurons)

def generate_kernel():
  part = []
  part.append(random.randint(min_kernel, max_kernel))
  part.append(random.randint(min_kernel, max_kernel))
  return part

def generate_bn_layer():
  part = [BN_LAYER] 
  return part

def generate_dropout_layer():
  part = [DROPOUT_LAYER] 
  part.append(random.uniform(0,.5))  
  return part

def generate_conv_layer():
  part = [CONV_LAYER] 
  part.append(generate_neurons())
  part.extend(generate_kernel())  
  return part

def generate_upconv_layer():
  part = [UPCONV_LAYER] 
  part.append(generate_neurons())
  part.extend(generate_kernel())  
  return part

def create_offspring():
  ind = []
  layers = 0
  for i in range(max_layers):
    if i==0: #first layer always convolutational
      ind.extend(generate_conv_layer())      
      layers += 1
    elif random.uniform(0,1)<.5:
      #add convolution layer
      ind.extend(generate_conv_layer())
      layers += 1
      if random.uniform(0,1)<.5:
        #add batchnormalization
        ind.extend(generate_bn_layer())
      if random.uniform(0,1) < .5:
        ind.extend(generate_dropout_layer()) 
  for i in range(layers):
    ind.extend(generate_upconv_layer())
    if random.uniform(0,1)<.5:
      #add batchnormalization
      ind.extend(generate_bn_layer())
    if random.uniform(0,1) < .5:
      ind.extend(generate_dropout_layer())
  return ind
        
individual = create_offspring()
print(individual)
# Out:
# [-1, 23, 3, 3, -1, 117, 3, 3, -4, 0.09864610277019042, -1, 25, 3, 3, -3, -1, 96, 3, 3, -3, -1, 109, 3, 3, -3, -1, 74, 3, 3, -3, -1, 73, 3, 3, -3, -4, 0.18364457224486702, -2, 95, 3, 3, -3, -2, 73, 3, 3, -4, 0.13764225099368715, -2, 127, 3, 3, -4, 0.29458943194283843, -2, 124, 3, 3, -4, 0.13232559767286411, -2, 128, 3, 3, -4, 0.1167939615786936, -2, 64, 3, 3, -2, 57, 3, 3, -3]

# %%
def padding(gene):
  return "same" if gene == 1 else "valid"

def build_model(individual):
  input_layer = Input(shape=(28, 28, 1))  
  il = len(individual)
  i = 0
  x = input_layer
  while i < il:    
    if individual[i] == CONV_LAYER:      
      pad="same" 
      n = individual[i+1]
      k = (individual[i+2], individual[i+3])
      i += CONV_LAYER_LEN        
      x = layers.Conv2D(n, k, activation='relu', padding=pad)(x) 
      if x.shape[1] > 7:
        x = layers.MaxPool2D( (2, 2), padding='same')(x)
    elif individual[i] == BN_LAYER: #add batchnormal layer
      x = layers.BatchNormalization()(x)
      i += BN_LAYER_LEN      
    elif individual[i] == DROPOUT_LAYER: #add dropout layer            
      x = layers.Dropout(individual[i+1])(x) 
      i += DROPOUT_LAYER_LEN
    elif individual[i] == UPCONV_LAYER:
      pad="same"
      n = individual[i+1]
      k = (individual[i+2], individual[i+3])        
      x = layers.Conv2D(n, k, activation='relu', padding=pad)(x)   
      x = layers.UpSampling2D((2, 2))(x)   
      i += CONV_LAYER_LEN   
      if x.shape[1] == (28):
        break #model is complete
    else:
      break
  if x.shape[1] == 14:
    x = layers.UpSampling2D((2, 2))(x)
    
  output_layer = layers.Conv2D(1, (3, 3), padding='same')(x)
  model = Model(input_layer, output_layer)
  model.compile(optimizer='adam', loss='mse')
  return model

model = build_model(individual) 
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 23)        230
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 23)        0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 14, 14, 117)       24336
#
#  max_pooling2d_4 (MaxPoolin  (None, 7, 7, 117)         0
#  g2D)
#
#  dropout (Dropout)           (None, 7, 7, 117)         0
#
#  conv2d_9 (Conv2D)           (None, 7, 7, 25)          26350
#
#  batch_normalization (Batch  (None, 7, 7, 25)          100
#  Normalization)
#
#  conv2d_10 (Conv2D)          (None, 7, 7, 96)          21696
#
#  batch_normalization_1 (Bat  (None, 7, 7, 96)          384
#  chNormalization)
#
#  conv2d_11 (Conv2D)          (None, 7, 7, 109)         94285
#
#  batch_normalization_2 (Bat  (None, 7, 7, 109)         436
#  chNormalization)
#
#  conv2d_12 (Conv2D)          (None, 7, 7, 74)          72668
#
#  batch_normalization_3 (Bat  (None, 7, 7, 74)          296
#  chNormalization)
#
#  conv2d_13 (Conv2D)          (None, 7, 7, 73)          48691
#
#  batch_normalization_4 (Bat  (None, 7, 7, 73)          292
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 7, 7, 73)          0
#
#  conv2d_14 (Conv2D)          (None, 7, 7, 95)          62510
#
#  up_sampling2d_3 (UpSamplin  (None, 14, 14, 95)        0
#  g2D)
#
#  batch_normalization_5 (Bat  (None, 14, 14, 95)        380
#  chNormalization)
#
#  conv2d_15 (Conv2D)          (None, 14, 14, 73)        62488
#
#  up_sampling2d_4 (UpSamplin  (None, 28, 28, 73)        0
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 28, 28, 1)         658
#
# =================================================================
# Total params: 415800 (1.59 MB)
# Trainable params: 414856 (1.58 MB)
# Non-trainable params: 944 (3.69 KB)
# _________________________________________________________________

# %%
individual = create_offspring() 
model = build_model(individual)
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_17 (Conv2D)          (None, 28, 28, 117)       1170
#
#  max_pooling2d_5 (MaxPoolin  (None, 14, 14, 117)       0
#  g2D)
#
#  conv2d_18 (Conv2D)          (None, 14, 14, 93)        98022
#
#  max_pooling2d_6 (MaxPoolin  (None, 7, 7, 93)          0
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 7, 7, 101)         84638
#
#  dropout_2 (Dropout)         (None, 7, 7, 101)         0
#
#  conv2d_20 (Conv2D)          (None, 7, 7, 40)          36400
#
#  conv2d_21 (Conv2D)          (None, 7, 7, 68)          24548
#
#  dropout_3 (Dropout)         (None, 7, 7, 68)          0
#
#  conv2d_22 (Conv2D)          (None, 7, 7, 119)         72947
#
#  up_sampling2d_5 (UpSamplin  (None, 14, 14, 119)       0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 14, 14, 119)       0
#
#  conv2d_23 (Conv2D)          (None, 14, 14, 82)        87904
#
#  up_sampling2d_6 (UpSamplin  (None, 28, 28, 82)        0
#  g2D)
#
#  conv2d_24 (Conv2D)          (None, 28, 28, 1)         739
#
# =================================================================
# Total params: 406368 (1.55 MB)
# Trainable params: 406368 (1.55 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Creating Mate/Mutation Operators

# %%
#@title Start of Mate/Mutation Operators
def get_layers(ind, layer_type):
  return [a for a in range(len(ind)) if ind[a] == layer_type]

def swap(ind1, iv1, ind2, iv2, ll):
  ch1 = ind1[iv1:iv1+ll]
  ch2 = ind2[iv2:iv2+ll] 
  ind1[iv1:iv1+ll] = ch2
  ind2[iv2:iv2+ll] = ch1
  return ind1, ind2

def swap_layers(ind1, ind2, layer_type, layer_len):
  c1, c2 = get_layers(ind1, layer_type), get_layers(ind2, layer_type) 
  min_c = min(len(c1), len(c2))
  for i in range(min_c):
    if random.random() < 1:
      i1 = random.randint(0, len(c1)-1)
      i2 = random.randint(0, len(c2)-1)      
      iv1 = c1.pop(i1)
      iv2 = c2.pop(i2)    
      ind1, ind2 = swap(ind1, iv1, ind2, iv2, layer_len) 
  return ind1, ind2 

def crossover(ind1, ind2):  
  ind1, ind2 = swap_layers(ind1, ind2, CONV_LAYER, CONV_LAYER_LEN)
  ind1, ind2 = swap_layers(ind1, ind2, UPCONV_LAYER, UPCONV_LAYER_LEN)
  ind1, ind2 = swap_layers(ind1, ind2, BN_LAYER, BN_LAYER_LEN)
  ind1, ind2 = swap_layers(ind1, ind2, DROPOUT_LAYER, DROPOUT_LAYER_LEN)
  return ind1, ind2  

ind1 = create_offspring()
ind2 = create_offspring()
print(ind1)
print(ind2)

ind1, ind2 = crossover(ind1, ind2)
print(ind1)
print(ind2)

model = build_model(ind1)
model.summary()
model = build_model(ind2)
model.summary()
# Out:
# [-1, 47, 3, 3, -1, 128, 3, 3, -4, 0.05363018430737526, -1, 100, 3, 3, -4, 0.026553941659314684, -2, 55, 3, 3, -2, 76, 3, 3, -2, 123, 3, 3, -3, -4, 0.31503508441566086]
# [-1, 68, 3, 3, -1, 69, 3, 3, -1, 128, 3, 3, -3, -4, 0.23584014111875418, -1, 48, 3, 3, -3, -2, 47, 3, 3, -4, 0.4552193519610741, -2, 19, 3, 3, -3, -4, 0.04154623081975495, -2, 54, 3, 3, -3, -2, 71, 3, 3, -3, -4, 0.21078482127939396]
# [-1, 128, 3, 3, -1, 69, 3, 3, -4, 0.21078482127939396, -1, 48, 3, 3, -4, 0.4552193519610741, -2, 71, 3, 3, -2, 54, 3, 3, -2, 47, 3, 3, -3, -4, 0.04154623081975495]
# [-1, 68, 3, 3, -1, 128, 3, 3, -1, 47, 3, 3, -3, -4, 0.23584014111875418, -1, 100, 3, 3, -3, -2, 123, 3, 3, -4, 0.026553941659314684, -2, 19, 3, 3, -3, -4, 0.31503508441566086, -2, 76, 3, 3, -3, -2, 55, 3, 3, -3, -4, 0.05363018430737526]
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_25 (Conv2D)          (None, 28, 28, 128)       1280
#
#  max_pooling2d_7 (MaxPoolin  (None, 14, 14, 128)       0
#  g2D)
#
#  conv2d_26 (Conv2D)          (None, 14, 14, 69)        79557
#
#  max_pooling2d_8 (MaxPoolin  (None, 7, 7, 69)          0
#  g2D)
#
#  dropout_5 (Dropout)         (None, 7, 7, 69)          0
#
#  conv2d_27 (Conv2D)          (None, 7, 7, 48)          29856
#
#  dropout_6 (Dropout)         (None, 7, 7, 48)          0
#
#  conv2d_28 (Conv2D)          (None, 7, 7, 71)          30743
#
#  up_sampling2d_7 (UpSamplin  (None, 14, 14, 71)        0
#  g2D)
#
#  conv2d_29 (Conv2D)          (None, 14, 14, 54)        34560
#
#  up_sampling2d_8 (UpSamplin  (None, 28, 28, 54)        0
#  g2D)
#
#  conv2d_30 (Conv2D)          (None, 28, 28, 1)         487
#
# =================================================================
# Total params: 176483 (689.39 KB)
# Trainable params: 176483 (689.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_31 (Conv2D)          (None, 28, 28, 68)        680
#
#  max_pooling2d_9 (MaxPoolin  (None, 14, 14, 68)        0
#  g2D)
#
#  conv2d_32 (Conv2D)          (None, 14, 14, 128)       78464
#
#  max_pooling2d_10 (MaxPooli  (None, 7, 7, 128)         0
#  ng2D)
#
#  conv2d_33 (Conv2D)          (None, 7, 7, 47)          54191
#
#  batch_normalization_6 (Bat  (None, 7, 7, 47)          188
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 7, 7, 47)          0
#
#  conv2d_34 (Conv2D)          (None, 7, 7, 100)         42400
#
#  batch_normalization_7 (Bat  (None, 7, 7, 100)         400
#  chNormalization)
#
#  conv2d_35 (Conv2D)          (None, 7, 7, 123)         110823
#
#  up_sampling2d_9 (UpSamplin  (None, 14, 14, 123)       0
#  g2D)
#
#  dropout_8 (Dropout)         (None, 14, 14, 123)       0
#
#  conv2d_36 (Conv2D)          (None, 14, 14, 19)        21052
#
#  up_sampling2d_10 (UpSampli  (None, 28, 28, 19)        0
#  ng2D)
#
#  conv2d_37 (Conv2D)          (None, 28, 28, 1)         172
#
# =================================================================
# Total params: 308370 (1.18 MB)
# Trainable params: 308076 (1.18 MB)
# Non-trainable params: 294 (1.15 KB)
# _________________________________________________________________

# %%
#@title Mutation
def mutate(part, layer_type):
  if layer_type == CONV_LAYER and len(part)==CONV_LAYER_LEN:
    part[1] = int(part[1] * random.uniform(.9, 1.1))
    part[2] = random.randint(min_kernel, max_kernel)
    part[3] = random.randint(min_kernel, max_kernel)
  elif layer_type == UPCONV_LAYER and len(part)==UPCONV_LAYER_LEN:
    part[1] = random.randint(min_kernel, max_kernel)
    part[2] = random.randint(min_kernel, max_kernel)
  elif layer_type == DROPOUT_LAYER and len(part)==DROPOUT_LAYER_LEN:
    part[1] = random.uniform(0, .5) 
  else:
    error = f"mutate ERROR {part}"    
    raise Exception(error) 
  return part

def mutate_layers(ind, layer_type, layer_len):
  layers = get_layers(ind1, layer_type)
  for layer in layers:
    if random.random() < 1:
      try:
        ind[layer:layer+layer_len] = mutate(
            ind[layer:layer+layer_len], layer_type) 
      except:
        print(layers)
  return ind      

print(ind1)

def mutation(ind):    
  ind = mutate_layers(ind, CONV_LAYER, CONV_LAYER_LEN)
  ind = mutate_layers(ind, DROPOUT_LAYER, DROPOUT_LAYER_LEN)    
  ind = mutate_layers(ind, UPCONV_LAYER, UPCONV_LAYER_LEN)
  return ind,

ind, = mutation(ind1)
print(ind)
model = build_model(ind1)
model.summary()
# Out:
# [-1, 128, 3, 3, -1, 69, 3, 3, -4, 0.21078482127939396, -1, 48, 3, 3, -4, 0.4552193519610741, -2, 71, 3, 3, -2, 54, 3, 3, -2, 47, 3, 3, -3, -4, 0.04154623081975495]
# [-1, 122, 3, 3, -1, 74, 3, 3, -4, 0.06214506215944221, -1, 44, 3, 3, -4, 0.3996726040951653, -2, 3, 3, 3, -2, 3, 3, 3, -2, 3, 3, 3, -3, -4, 0.4823108850648599]
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_38 (Conv2D)          (None, 28, 28, 122)       1220
#
#  max_pooling2d_11 (MaxPooli  (None, 14, 14, 122)       0
#  ng2D)
#
#  conv2d_39 (Conv2D)          (None, 14, 14, 74)        81326
#
#  max_pooling2d_12 (MaxPooli  (None, 7, 7, 74)          0
#  ng2D)
#
#  dropout_9 (Dropout)         (None, 7, 7, 74)          0
#
#  conv2d_40 (Conv2D)          (None, 7, 7, 44)          29348
#
#  dropout_10 (Dropout)        (None, 7, 7, 44)          0
#
#  conv2d_41 (Conv2D)          (None, 7, 7, 3)           1191
#
#  up_sampling2d_11 (UpSampli  (None, 14, 14, 3)         0
#  ng2D)
#
#  conv2d_42 (Conv2D)          (None, 14, 14, 3)         84
#
#  up_sampling2d_12 (UpSampli  (None, 28, 28, 3)         0
#  ng2D)
#
#  conv2d_43 (Conv2D)          (None, 28, 28, 1)         28
#
# =================================================================
# Total params: 113197 (442.18 KB)
# Trainable params: 113197 (442.18 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#@title Setting up the Creator
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

# %%
#@title Create Individual and Population
toolbox = base.Toolbox()
toolbox.register("autoencoder", create_offspring)
toolbox.register("individual", tools.initIterate, creator.Individual, toolbox.autoencoder)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("select", tools.selTournament, tournsize=5)

# %%
#@title Register Crossover and Mutation
toolbox.register("mate", crossover)
toolbox.register("mutate", mutation)

# %%
#@title Register Evaluation
def clamp(num, min_value, max_value):
   return max(min(num, max_value), min_value)

def train(model):  
  history = model.fit(train_images, train_images, epochs=3,
                      batch_size=2048, validation_data=(test_images, test_images),
                      verbose=0)
  return model, history

fits = []

def evaluate(individual): 
  global fits
  try:
    model = build_model(individual)
    model, history = train(model)        
    fitness = history.history["val_loss"]
    fits.append(fitness)
    print(".", end='')    
    return clamp(fitness, 0, np.nanmax(fits)),
  except:
    return np.nanmax(fits),  

toolbox.register("evaluate", evaluate)

# %%
#@title Optimize the Weights { run: "auto" }
MU = 100 #@param {type:"slider", min:5, max:100, step:1}
NGEN = 1 #@param {type:"slider", min:1, max:10, step:1}
RGEN = 1 #@param {type:"slider", min:1, max:5, step:1}
CXPB = .6
MUTPB = .3

random.seed(64)

pop = toolbox.population(n=MU)
hof = tools.HallOfFame(1)
stats = tools.Statistics(lambda ind: ind.fitness.values)
stats.register("avg", np.mean)
stats.register("std", np.std)
stats.register("min", np.min)
stats.register("max", np.max)

# %%
best = None
groups = { "fitness" : {"min", "max"}}
plotlosses = PlotLosses(groups=groups)

for g in range(NGEN):
  pop, logbook = algorithms.eaSimple(pop, toolbox, 
            cxpb=CXPB, mutpb=MUTPB, ngen=RGEN, stats=stats, halloffame=hof, verbose=False)
  best = hof[0] 
  
  print(f"Gen ({(g+1)*RGEN})")      
  for l in logbook:
    plotlosses.update({'min': l["min"], 'max': l["max"]})
  plotlosses.send()  # draw, update logs, etc
# Out:
# .................

# %%
model = build_model(best)

EPOCHS = 10
history = reset_history()

for i in range(EPOCHS):
  history = model.fit(train_images, train_images, epochs=1, batch_size=2048, validation_data=(test_images, test_images))
  pred_images = model.predict(test_images[:25])
  clear_output()
  plot_results(25, pred_images[:25], test_labels[:25], history)
